# %% [markdown]
# <a href="https://colab.research.google.com/github/khushaldhakate/Pandas-Extraction/blob/main/project3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
df=pd.read_csv('IPL.csv')
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
print(f"Your rows are {df.shape[0]} and your column are {df.shape[1]}")
# Out:
# Your rows are 74 and your column are 20

# %%
df.shape[0]
# Out:
# 74

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   match_id             74 non-null     int64
#  1   date                 74 non-null     object
#  2   venue                74 non-null     object
#  3   team1                74 non-null     object
#  4   team2                74 non-null     object
#  5   stage                74 non-null     object
#  6   toss_winner          74 non-null     object
#  7   toss_decision        74 non-null     object
#  8   first_ings_score     74 non-null     int64
#  9   first_ings_wkts      74 non-null     int64
#  10  second_ings_score    74 non-null     int64
#  11  second_ings_wkts     74 non-null     int64
#  12  match_winner         74 non-null     object
#  13  won_by               74 non-null     object
#  14  margin               74 non-null     int64
# ...

# %%
df.isnull().sum()
# Out:
# match_id               0
# date                   0
# venue                  0
# team1                  0
# team2                  0
# stage                  0
# toss_winner            0
# toss_decision          0
# first_ings_score       0
# first_ings_wkts        0
# second_ings_score      0
# second_ings_wkts       0
# match_winner           0
# won_by                 0
# margin                 0
# player_of_the_match    0
# top_scorer             0
# highscore              0
# best_bowling           0
# best_bowling_figure    0
# dtype: int64

# %%
match_win=df['match_winner'].value_counts()
sns.barplot(y=match_win.index,x=match_win.values,palette='viridis')
plt.title("Most Match win by team")
# Out:
# Text(0.5, 1.0, 'Most Match win by team')

# %%
sns.countplot(x=df['toss_decision'],palette='rainbow')
plt.title("Toss decision Trends")
# Out:
# Text(0.5, 1.0, 'Toss decision Trends')

# %%
count=df[df['toss_winner']==df['match_winner']]['match_id'].count()
percentage=(count*100)/df.shape[0]
percentage
# Out:
# np.float64(48.648648648648646)

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
sns.countplot(x=df['won_by'])
plt.title("Won by")
# Out:
# Text(0.5, 1.0, 'Won by')

# %%
count=df['player_of_the_match'].value_counts().max()
count
# Out:
# 4

# %%
count=df['player_of_the_match'].value_counts().head(10)
count
# Out:
# player_of_the_match
# Kuldeep Yadav        4
# Jos Buttler          3
# Wanindu Hasaranga    2
# Umesh Yadav          2
# Quinton de Kock      2
# Shubman Gill         2
# Avesh Khan           2
# Dinesh Karthik       2
# Hardik Pandya        2
# Rahul Tripathi       2
# Name: count, dtype: int64

# %%
sns.barplot(x=count.values,y=count.index,palette='mako')
plt.title("Top 10 Player")
# Out:
# Text(0.5, 1.0, 'Top 10 Player')

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
count=df['top_scorer'].value_counts().head(2)
count
# Out:
# top_scorer
# Jos Buttler        7
# Quinton de Kock    5
# Name: count, dtype: int64

# %%
high=df.groupby('top_scorer')['highscore'].sum()
high
# Out:
# top_scorer
# Abhishek Sharma        122
# Aiden Markram           57
# Andre Russell          119
# David Miller            94
# David Warner           213
# Deepak Hooda           114
# Devon Conway           143
# Dinesh Karthik          66
# Faf du Plessis         257
# Hardik Pandya          154
# Ishan Kishan           180
# Jos Buttler            651
# KL Rahul               351
# Kane Williamson         57
# Liam Livingstone       239
# MS Dhoni                86
# Mitchell Marsh         152
# Moeen Ali               93
# Nitish Rana             57
# Pat Cummins             56
# Quinton de Kock        377
# Rahul Tripathi         147
# Rajat Patidar          112
# Riyan Parag             56
# Ruturaj Gaikwad         99
# Sai Sudharsan           65
# Sanju Samson            54
# Sherfane Rutherford     28
# Shikhar Dhawan         158
# Shimron Hetmyer         59
# Shivam Dube             95
# Shubman Gill           288
# Suryakumar Yadav        68
# Tilak Varma             51
# ...

# %%
high=df.groupby('top_scorer').sum()
high
# Out:
#                      match_id  \
# top_scorer
# Abhishek Sharma            53
# Aiden Markram               5
# Andre Russell              69
# David Miller               29
# David Warner              101
# Deepak Hooda               67
# Devon Conway              104
# Dinesh Karthik             27
# Faf du Plessis             88
# Hardik Pandya              59
# Ishan Kishan              127
# Jos Buttler               274
# KL Rahul                  120
# Kane Williamson            21
# Liam Livingstone          169
# MS Dhoni                   60
# Mitchell Marsh            122
# Moeen Ali                  68
# Nitish Rana                41
# Pat Cummins                14
# Quinton de Kock           183
# Rahul Tripathi             90
# Rajat Patidar              72
# Riyan Parag                39
# Ruturaj Gaikwad            46
# Sai Sudharsan              48
# Sanju Samson               47
# Sherfane Rutherford         6
# Shikhar Dhawan             61
# ...

# %%
high=df.groupby('top_scorer')['highscore'].sum().sort_values(ascending=False).head(2
                                                                                   )

high
# Out:
# top_scorer
# Jos Buttler        651
# Quinton de Kock    377
# Name: highscore, dtype: int64

# %%
high.plot(kind='barh',color='red')
# Out:
# <Axes: ylabel='top_scorer'>

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
df['highest_wicktes']=df['best_bowling_figure'].apply(lambda x:x.split('--')[0])
df['highest_wicktes']=df['highest_wicktes'].astype(int)
top_bowlers=df.groupby('best_bowling')['highest_wicktes'].sum().sort_values(ascending=False)

# %%
top_bowlers
# Out:
# best_bowling
# Yuzvendra Chahal      17
# Jasprit Bumrah        11
# Kuldeep Yadav         11
# Rashid Khan           11
# Josh Hazlewood        10
# Kagiso Rabada         10
# Avesh Khan            10
# Umran Malik            9
# Wanindu Hasaranga      9
# T Natarajan            8
# Maheesh Theekshana     7
# Mohsin Khan            7
# Lockie Ferguson        7
# Andre Russell          7
# Daniel Sams            7
# Harshal Patel          6
# Dwayne Bravo           6
# Prasidh Krishna        6
# Mohammed Shami         5
# Shardul Takur          4
# Ravi Bishnoi           4
# Hardik Pandya          4
# Umesh Yadav            4
# Mukesh Choudhary       4
# Odean Smith            4
# Kuldeep Sen            4
# Krunal Pandya          3
# Khaleel Ahmed          3
# Harpreet Brar          3
# Rahul Chahar           3
# Ramandeep Singh        3
# Moeen Ali              3
# Chetan Sakariya        2
# Axar Patel             2
# Pradeep Sangwan        2
# Murugan Ashwin         2
# ...

# %%
top_bowlers.plot(kind='barh',color='pink')
# Out:
# <Axes: ylabel='best_bowling'>

# %%
venue=df['venue'].value_counts()
venue
# Out:
# venue
# Wankhede Stadium, Mumbai                        21
# Dr DY Patil Sports Academy, Mumbai              20
# Brabourne Stadium, Mumbai                       16
# Maharashtra Cricket Association Stadium,Pune    13
# Eden Gardens, Kolkata                            2
# Narendra Modi Stadium, Ahmedabad                 2
# Name: count, dtype: int64

# %%
sns.barplot(y=venue.index,x=venue.values,palette='rainbow')
# Out:
# <Axes: ylabel='venue'>

# %%
df[df['won_by'] == 'Runs'].sort_values(by = 'margin',ascending=False).head(1)[['match_winner','margin']]
# Out:
#    match_winner  margin
# 54      Chennai      91

# %%
df.head(2)
# Out:
#    match_id           date                      venue    team1    team2  \
# 0         1  March 26,2022   Wankhede Stadium, Mumbai  Chennai  Kolkata
# 1         2  March 27,2022  Brabourne Stadium, Mumbai    Delhi   Mumbai
#
#    stage toss_winner toss_decision  first_ings_score  first_ings_wkts  ...  \
# 0  Group     Kolkata         Field               131                5  ...
# 1  Group       Delhi         Field               177                5  ...
#
#    second_ings_wkts  match_winner   won_by margin  player_of_the_match  \
# 0                 4       Kolkata  Wickets      6          Umesh Yadav
# 1                 6         Delhi  Wickets      4        Kuldeep Yadav
#
#      top_scorer highscore   best_bowling best_bowling_figure highest_wicktes
# 0      MS Dhoni        50   Dwayne Bravo               3--20               3
# 1  Ishan Kishan        81  Kuldeep Yadav               3--18               3
#
# [2 rows x 21 columns]

# %%
df[df['highscore']==df['highscore'].max()][['top_scorer','highscore']]
# Out:
#          top_scorer  highscore
# 65  Quinton de Kock        140

# %%
df[df['highest_wicktes']==df['highest_wicktes'].max()][['best_bowling_figure','best_bowling']]
# Out:
#    best_bowling_figure       best_bowling
# 29               5--40   Yuzvendra Chahal
# 39               5--25        Umran Malik
# 53               5--18  Wanindu Hasaranga
# 55               5--10     Jasprit Bumrah
