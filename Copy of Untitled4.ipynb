# %%
import pandas as pd
import numpy as np

# %%
labels=['A','B','C']
mylists=[10,20,30]
arr=np.array([10,20,30])
d={1:11,2:22,3:33}

# %%
pd.Series(mylists)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(mylists,index=d)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64
